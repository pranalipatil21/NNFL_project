# %%
import pandas as pd

# Load the dataset
file_path = '/mnt/data/Project_2.O.csv'
data = pd.read_csv('C:/Users/prano/Downloads/Project_2.O.csv')

# Convert the total battery capacity from kW to kWh
# Assuming 1 hour of supply time, the conversion is direct
total_battery_capacity_kwh = 9.73228  # This is the battery capacity in kWh

# Use columns from the dataset
soc = data['Pack SoC']  # State of Charge in percentage
voltage = data['Voltage']  # Voltage in volts
input_power = data['input_power']  # Input power in kW (assumed)

# Typical values for calculations
energy_consumption_rate_kwh_per_km = 0.2  # kWh per kilometer (adjust as necessary)
average_speed_kmph = 60  # Assuming an average speed of 60 km/h

# Step 1: Calculate remaining energy in kWh
remaining_energy_kwh = (soc / 100) * total_battery_capacity_kwh

# Step 2: Calculate remaining range (in kilometers) based on energy consumption rate
remaining_range_km = remaining_energy_kwh / energy_consumption_rate_kwh_per_km

# Step 3: Calculate the remaining time in hours (distance / speed)
remaining_time_hours = remaining_range_km / average_speed_kmph

# Step 4: Convert remaining time from hours to minutes
remaining_time_minutes = remaining_time_hours * 60

# Add the calculated remaining time in minutes to the dataset
data['Remaining Time (minutes)'] = remaining_time_minutes

# Display the first few rows with the new column showing calculated remaining time
output = data[['Pack SoC', 'Voltage', 'input_power', 'Remaining Time (minutes)']]
print(output.head())
# Out:
#    Pack SoC  Voltage  input_power  Remaining Time (minutes)
# 0      94.0     57.3      0.00573                 45.741716
# 1      94.0     57.3      0.00573                 45.741716
# 2      94.0     57.3      0.00573                 45.741716
# 3      94.0     57.3      0.00573                 45.741716
# 4      94.0     57.3      0.00573                 45.741716

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Load the dataset
data = pd.read_csv('C:/Users/prano/Downloads/Project_2.O.csv')

# Use columns from the dataset (Pack SoC, Voltage, input_power) to predict Remaining Time
X = data[['Pack SoC', 'Voltage', 'input_power']]  # Input features

# Total battery capacity in kWh (as provided earlier)
total_battery_capacity_kwh = 9.73228
energy_consumption_rate_kwh_per_km = 0.2  # kWh per kilometer
average_speed_kmph = 60  # Average speed in km/h

# Calculate remaining energy in kWh
remaining_energy_kwh = (data['Pack SoC'] / 100) * total_battery_capacity_kwh

# Calculate remaining range in kilometers
remaining_range_km = remaining_energy_kwh / energy_consumption_rate_kwh_per_km

# Calculate the remaining time in hours (distance / speed)
remaining_time_hours = remaining_range_km / average_speed_kmph

# Convert remaining time to minutes
data['Remaining Time (minutes)'] = remaining_time_hours * 60

# Now use this calculated column as the target variable (y)
y = data['Remaining Time (minutes)']  # Output label (target)

# Step 1: Split the data into training and testing sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 2: Scale the features for better performance
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 3: Build the ANN model
model = Sequential()

# Input Layer + Hidden Layer 1 (with 32 neurons and ReLU activation)
model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))

# Hidden Layer 2 (with 16 neurons and ReLU activation)
model.add(Dense(16, activation='relu'))

# Output Layer (1 neuron, predicting the remaining time in minutes)
model.add(Dense(1))

# Step 4: Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Step 5: Early Stopping to avoid overfitting (patience of 10 epochs)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Step 6: Train the model using the training data with early stopping
history = model.fit(X_train_scaled, y_train, 
                    validation_split=0.2, 
                    epochs=200,  # Set a large number of epochs
                    callbacks=[early_stopping], 
                    verbose=1)

# Step 7: Evaluate the model using the test data
test_loss = model.evaluate(X_test_scaled, y_test)

# Step 8: Make predictions on the test data
y_pred = model.predict(X_test_scaled)

# Convert predictions to a 1D array
y_pred = y_pred.flatten()

# Step 9: Calculate regression accuracy metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Step 10: Print overall loss values after training
final_training_loss = history.history['loss'][-1]
final_validation_loss = history.history['val_loss'][-1]
print(f'Final Training Loss: {final_training_loss}')
print(f'Final Validation Loss: {final_validation_loss}')

# Display the metrics
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'R-squared (R²): {r2}')

# Step 11: Print actual vs predicted values for test data
print('Actual vs Predicted Remaining Time (minutes):')
for actual, predicted in zip(y_test[:10], y_pred[:10]):  # Display first 10 predictions
    print(f'Actual: {actual:.2f}, Predicted: {predicted:.2f}')


final_training_loss = history.history['loss'][-1]
final_validation_loss = history.history['val_loss'][-1]
print(f'Final Training Loss: {final_training_loss}')
print(f'Final Validation Loss: {final_validation_loss}')

# Step 12: Take user input for prediction
def predict_remaining_time():
    try:
        # Take user input for Pack SoC, Voltage, and input_power
        pack_soc = float(input("Enter the Pack SoC (%): "))
        voltage = float(input("Enter the Voltage (V): "))
        input_power = float(input("Enter the Input Power (kW): "))

        # Prepare the user input as a single-row DataFrame
        user_input = pd.DataFrame([[pack_soc, voltage, input_power]], 
                                  columns=['Pack SoC', 'Voltage', 'input_power'])

        # Scale the input using the same scaler used on training data
        user_input_scaled = scaler.transform(user_input)

        # Predict the remaining time
        predicted_time = model.predict(user_input_scaled)

        # Output the predicted time in minutes
        print(f'Predicted Remaining Time: {predicted_time[0][0]:.2f} minutes')
    except ValueError:
        print("Invalid input. Please enter numeric values.")

# Call the function to take input from the user and predict
predict_remaining_time()
# Out:
# Epoch 1/200
# C:\Users\prano\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1762.3372 - val_loss: 1647.9974
# Epoch 2/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1614.3674 - val_loss: 1393.5587
# Epoch 3/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1303.1487 - val_loss: 939.6408
# Epoch 4/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 821.2204 - val_loss: 474.5025
# Epoch 5/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 401.0673 - val_loss: 240.9066
# Epoch 6/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 232.6552 - val_loss: 172.3837
# Epoch 7/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 170.8234 - val_loss: 130.4257
# Epoch 8/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 128.9927 - val_loss: 95.2506
# Epoch 9/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 90.7882 - val_loss: 68.2775
# Epoch 10/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 63.5293 - val_loss: 49.7774
# Epoch 11/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.9378 - val_loss: 36.3813
# Epoch 12/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.9076 - val_loss: 27.6824
# Epoch 13/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25.3318 - val_loss: 21.1567
# Epoch 14/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.1930 - val_loss: 16.4890
# Epoch 15/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.9526 - val_loss: 12.9375
# Epoch 16/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.9366 - val_loss: 10.3482
# Epoch 17/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8294 - val_loss: 8.4428
# Epoch 18/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7985 - val_loss: 7.0657
# Epoch 19/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9538 - val_loss: 5.9729
# Epoch 20/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5208 - val_loss: 5.1936
# Epoch 21/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1278 - val_loss: 4.5075
# Epoch 22/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0476 - val_loss: 3.9418
# Epoch 23/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4948 - val_loss: 3.5233
# Epoch 24/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8244 - val_loss: 3.1057
# Epoch 25/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4481 - val_loss: 2.7918
# Epoch 26/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5935 - val_loss: 2.4771
# Epoch 27/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1538 - val_loss: 2.2395
# Epoch 28/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8065 - val_loss: 2.0301
# Epoch 29/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6922 - val_loss: 1.8655
# Epoch 30/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5317 - val_loss: 1.6902
# Epoch 31/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3227 - val_loss: 1.5485
# Epoch 32/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2885 - val_loss: 1.4046
# Epoch 33/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0788 - val_loss: 1.2933
# Epoch 34/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9849 - val_loss: 1.1833
# Epoch 35/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9340 - val_loss: 1.0931
# Epoch 36/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8655 - val_loss: 1.0034
# Epoch 37/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8557 - val_loss: 0.9236
# Epoch 38/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7341 - val_loss: 0.8477
# Epoch 39/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7129 - val_loss: 0.7997
# Epoch 40/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6386 - val_loss: 0.7169
# Epoch 41/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5699 - val_loss: 0.6575
# Epoch 42/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5201 - val_loss: 0.6051
# Epoch 43/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5121 - val_loss: 0.5567
# Epoch 44/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4943 - val_loss: 0.5290
# Epoch 45/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4044 - val_loss: 0.4730
# Epoch 46/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3663 - val_loss: 0.4455
# Epoch 47/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3370 - val_loss: 0.4005
# Epoch 48/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3370 - val_loss: 0.3706
# Epoch 49/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3221 - val_loss: 0.3411
# Epoch 50/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2811 - val_loss: 0.3133
# Epoch 51/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2658 - val_loss: 0.2930
# Epoch 52/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2566 - val_loss: 0.2757
# Epoch 53/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2245 - val_loss: 0.2595
# Epoch 54/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2146 - val_loss: 0.2355
# Epoch 55/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2286 - val_loss: 0.2119
# Epoch 56/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1884 - val_loss: 0.2000
# Epoch 57/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1809 - val_loss: 0.1884
# Epoch 58/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1507 - val_loss: 0.1717
# Epoch 59/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1461 - val_loss: 0.1651
# Epoch 60/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1393 - val_loss: 0.1484
# Epoch 61/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1377 - val_loss: 0.1438
# Epoch 62/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1202 - val_loss: 0.1356
# Epoch 63/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1251 - val_loss: 0.1238
# Epoch 64/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1197 - val_loss: 0.1150
# Epoch 65/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1064 - val_loss: 0.1076
# Epoch 66/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0956 - val_loss: 0.1024
# Epoch 67/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0928 - val_loss: 0.0978
# Epoch 68/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0916 - val_loss: 0.0905
# Epoch 69/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0846 - val_loss: 0.0842
# Epoch 70/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0821 - val_loss: 0.0802
# Epoch 71/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0788 - val_loss: 0.0759
# Epoch 72/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0699 - val_loss: 0.0726
# Epoch 73/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0719 - val_loss: 0.0716
# Epoch 74/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0685 - val_loss: 0.0648
# Epoch 75/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0689 - val_loss: 0.0626
# Epoch 76/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0597 - val_loss: 0.0602
# Epoch 77/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0585 - val_loss: 0.0560
# Epoch 78/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0555 - val_loss: 0.0532
# Epoch 79/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0515 - val_loss: 0.0502
# Epoch 80/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0522 - val_loss: 0.0485
# Epoch 81/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0471 - val_loss: 0.0457
# Epoch 82/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0470 - val_loss: 0.0446
# Epoch 83/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0435 - val_loss: 0.0414
# Epoch 84/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0395 - val_loss: 0.0397
# Epoch 85/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0434 - val_loss: 0.0377
# Epoch 86/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0401 - val_loss: 0.0369
# Epoch 87/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0353 - val_loss: 0.0346
# Epoch 88/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0371 - val_loss: 0.0330
# Epoch 89/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0318 - val_loss: 0.0314
# Epoch 90/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0315 - val_loss: 0.0320
# Epoch 91/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0327 - val_loss: 0.0290
# Epoch 92/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0295 - val_loss: 0.0282
# Epoch 93/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0289 - val_loss: 0.0267
# Epoch 94/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0302 - val_loss: 0.0329
# Epoch 95/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0362 - val_loss: 0.0246
# Epoch 96/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0267 - val_loss: 0.0253
# Epoch 97/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0247 - val_loss: 0.0232
# Epoch 98/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0274 - val_loss: 0.0233
# Epoch 99/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0247 - val_loss: 0.0237
# Epoch 100/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0260 - val_loss: 0.0225
# Epoch 101/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0217 - val_loss: 0.0222
# Epoch 102/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0213 - val_loss: 0.0219
# Epoch 103/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0219 - val_loss: 0.0208
# Epoch 104/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0208 - val_loss: 0.0203
# Epoch 105/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0208 - val_loss: 0.0191
# Epoch 106/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0194 - val_loss: 0.0186
# Epoch 107/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0186 - val_loss: 0.0188
# Epoch 108/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - val_loss: 0.0197
# Epoch 109/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0196 - val_loss: 0.0178
# Epoch 110/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0211 - val_loss: 0.0166
# Epoch 111/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191 - val_loss: 0.0164
# Epoch 112/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - val_loss: 0.0167
# Epoch 113/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0162 - val_loss: 0.0151
# Epoch 114/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - val_loss: 0.0166
# Epoch 115/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0169 - val_loss: 0.0161
# Epoch 116/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - val_loss: 0.0152
# Epoch 117/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0165 - val_loss: 0.0167
# Epoch 118/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0148 - val_loss: 0.0136
# Epoch 119/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0141 - val_loss: 0.0132
# Epoch 120/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0135 - val_loss: 0.0130
# Epoch 121/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0142 - val_loss: 0.0143
# Epoch 122/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0166 - val_loss: 0.0129
# Epoch 123/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0132 - val_loss: 0.0118
# Epoch 124/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0112 - val_loss: 0.0142
# Epoch 125/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0153 - val_loss: 0.0124
# Epoch 126/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0114 - val_loss: 0.0111
# Epoch 127/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0103 - val_loss: 0.0111
# Epoch 128/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0116 - val_loss: 0.0100
# Epoch 129/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0097 - val_loss: 0.0109
# Epoch 130/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0119 - val_loss: 0.0121
# Epoch 131/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0107 - val_loss: 0.0106
# Epoch 132/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0103 - val_loss: 0.0113
# Epoch 133/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091 - val_loss: 0.0087
# Epoch 134/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - val_loss: 0.0095
# Epoch 135/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - val_loss: 0.0088
# Epoch 136/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0091 - val_loss: 0.0083
# Epoch 137/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - val_loss: 0.0144
# Epoch 138/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0280 - val_loss: 0.0080
# Epoch 139/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0069 - val_loss: 0.0069
# Epoch 140/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - val_loss: 0.0088
# Epoch 141/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - val_loss: 0.0059
# Epoch 142/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 143/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - val_loss: 0.0055
# Epoch 144/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0071
# Epoch 145/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 146/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - val_loss: 0.0065
# Epoch 147/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 148/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - val_loss: 0.0043
# Epoch 149/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - val_loss: 0.0042
# Epoch 150/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 151/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 152/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 153/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 154/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0047
# Epoch 155/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 156/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 157/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - val_loss: 0.0081
# Epoch 158/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0159 - val_loss: 0.0037
# Epoch 159/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - val_loss: 0.0044
# Epoch 160/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 161/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0226
# Epoch 162/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0198 - val_loss: 0.0036
# Epoch 163/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 164/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 165/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0037
# Epoch 166/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - val_loss: 0.0033
# Epoch 167/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 168/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 169/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 170/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - val_loss: 0.0042
# Epoch 171/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 172/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - val_loss: 0.0068
# Epoch 173/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 174/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 175/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 176/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 177/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 178/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 179/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 180/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 181/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 182/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 183/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 184/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 185/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 186/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 187/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 188/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 189/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 190/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 191/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 192/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 193/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 194/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 195/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 196/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1477e-04 - val_loss: 0.0017
# Epoch 197/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 198/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 199/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2833e-04 - val_loss: 0.0016
# Epoch 200/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0255e-04 - val_loss: 0.0013
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0042
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Final Training Loss: 0.0007973322062753141
# Final Validation Loss: 0.0012669481802731752
# Mean Absolute Error (MAE): 0.02357931181890098
# Mean Squared Error (MSE): 0.0036187454276212197
# Root Mean Squared Error (RMSE): 0.06015600907325236
# R-squared (R²): 0.9994754403997009
# Actual vs Predicted Remaining Time (minutes):
# Actual: 43.07, Predicted: 43.05
# Actual: 43.07, Predicted: 43.06
# Actual: 41.36, Predicted: 41.38
# Actual: 38.44, Predicted: 38.47
# Actual: 41.36, Predicted: 41.39
# Actual: 44.04, Predicted: 44.03
# Actual: 45.74, Predicted: 45.76
# Actual: 43.31, Predicted: 43.32
# Actual: 37.96, Predicted: 37.95
# Actual: 37.71, Predicted: 37.73
# Final Training Loss: 0.0007973322062753141
# Final Validation Loss: 0.0012669481802731752
# Enter the Pack SoC (%):  97
# Enter the Voltage (V):  52
# Enter the Input Power (kW):  9.7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Predicted Remaining Time: 51.57 minutes

# %%
# Create a new DataFrame with the features and actual/predicted values
output_data = pd.DataFrame({
    'Pack SoC': X_test['Pack SoC'].values,
    'Voltage': X_test['Voltage'].values,
    'input_power': X_test['input_power'].values,
    'Actual Remaining Time (minutes)': y_test.values,
    'Predicted Remaining Time (minutes)': y_pred
})

# Save the dataset to a CSV file
output_data.to_csv('predicted_vs_actual.csv', index=False)
